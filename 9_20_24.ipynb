# %% [markdown]
# <a href="https://colab.research.google.com/github/sdasilvas/NGG6050/blob/main/9_20_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Multiple comparisons
#
# 	•	Bonferroni correction: It adjusts the significance threshold by dividing  \alpha  by the number of tests. Any p-value below this adjusted threshold is considered significant.
# 	•	Benjamini-Hochberg procedure: It controls the false discovery rate by applying thresholds based on the rank of p-values.

# %% [markdown]
# First, simulate multiple (say, 1000) t-tests comparing two samples with equal means and standard deviations, and save the p-values. Obviously, at p<0.05 we expect that ~5% of the simulations to yield a "statistically significant" result (of rejecting the NULL hypothesis that the samples come from distributions with equal means).

# %%
import numpy as np
from scipy import stats

# Set parameters
n = 30  # Sample size for each group
mu1 = 50  # Mean of sample 1
mu2 = 50  # Mean of sample 2 (equal to mu1)
sigma = 10  # Standard deviation (same for both groups)
num_tests = 1000  # Number of t-tests

# Array to store p-values
p_values = []

# Simulate 1000 t-tests
for _ in range(num_tests):
    # Generate random samples for both groups
    sample1 = np.random.normal(mu1, sigma, n)
    sample2 = np.random.normal(mu2, sigma, n)

    # Perform two-sample t-test
    t_stat, p_value = stats.ttest_ind(sample1, sample2)

    # Store the p-value
    p_values.append(p_value)

# Print p-values
for i, p_value in enumerate(p_values, 1):
    print(f"Test {i}: p-value = {p_value:.4f}")

# Calculate the percent of significant p-values
significant_count = sum(p < alpha for p in p_values)
percent_significant = (significant_count / num_tests) * 100

# Print the result
print(f"Percentage of significant p-values (p < {alpha}): {percent_significant:.2f}%")
# Out:
# Test 1: p-value = 0.9729
# Test 2: p-value = 0.3853
# Test 3: p-value = 0.6226
# Test 4: p-value = 0.9509
# Test 5: p-value = 0.4285
# Test 6: p-value = 0.4374
# Test 7: p-value = 0.9114
# Test 8: p-value = 0.6674
# Test 9: p-value = 0.0032
# Test 10: p-value = 0.4951
# Test 11: p-value = 0.0356
# Test 12: p-value = 0.7274
# Test 13: p-value = 0.4653
# Test 14: p-value = 0.2630
# Test 15: p-value = 0.9086
# Test 16: p-value = 0.2769
# Test 17: p-value = 0.3094
# Test 18: p-value = 0.9711
# Test 19: p-value = 0.2167
# Test 20: p-value = 0.8434
# Test 21: p-value = 0.2644
# Test 22: p-value = 0.1209
# Test 23: p-value = 0.4791
# Test 24: p-value = 0.7268
# Test 25: p-value = 0.8193
# Test 26: p-value = 0.1674
# Test 27: p-value = 0.5636
# Test 28: p-value = 0.9915
# Test 29: p-value = 0.9736
# Test 30: p-value = 0.1699
# Test 31: p-value = 0.3535
# Test 32: p-value = 0.0268
# Test 33: p-value = 0.5843
# Test 34: p-value = 0.8899
# Test 35: p-value = 0.5446
# Test 36: p-value = 0.4816
# Test 37: p-value = 0.6123
# Test 38: p-value = 0.2474
# Test 39: p-value = 0.8953
# Test 40: p-value = 0.4869
# Test 41: p-value = 0.7622
# Test 42: p-value = 0.3947
# Test 43: p-value = 0.1892
# Test 44: p-value = 0.3986
# Test 45: p-value = 0.3450
# Test 46: p-value = 0.7614
# Test 47: p-value = 0.4651
# Test 48: p-value = 0.7553
# Test 49: p-value = 0.4886
# Test 50: p-value = 0.1236
# Test 51: p-value = 0.3775
# Test 52: p-value = 0.9984
# Test 53: p-value = 0.3505
# Test 54: p-value = 0.9130
# Test 55: p-value = 0.5670
# Test 56: p-value = 0.4202
# Test 57: p-value = 0.8419
# Test 58: p-value = 0.1935
# Test 59: p-value = 0.5491
# Test 60: p-value = 0.9351
# Test 61: p-value = 0.6616
# Test 62: p-value = 0.2471
# Test 63: p-value = 0.4348
# Test 64: p-value = 0.1807
# Test 65: p-value = 0.9350
# Test 66: p-value = 0.7395
# Test 67: p-value = 0.4618
# Test 68: p-value = 0.9009
# Test 69: p-value = 0.3530
# Test 70: p-value = 0.3346
# Test 71: p-value = 0.8293
# Test 72: p-value = 0.6042
# Test 73: p-value = 0.8129
# Test 74: p-value = 0.7138
# Test 75: p-value = 0.0180
# Test 76: p-value = 0.5200
# Test 77: p-value = 0.6471
# Test 78: p-value = 0.9658
# Test 79: p-value = 0.7044
# Test 80: p-value = 0.1620
# Test 81: p-value = 0.9199
# Test 82: p-value = 0.7712
# Test 83: p-value = 0.1329
# Test 84: p-value = 0.6309
# Test 85: p-value = 0.3825
# Test 86: p-value = 0.8792
# Test 87: p-value = 0.2914
# Test 88: p-value = 0.2777
# Test 89: p-value = 0.5258
# Test 90: p-value = 0.7889
# Test 91: p-value = 0.7423
# Test 92: p-value = 0.5067
# Test 93: p-value = 0.5160
# Test 94: p-value = 0.8390
# Test 95: p-value = 0.1713
# Test 96: p-value = 0.6953
# Test 97: p-value = 0.0595
# Test 98: p-value = 0.3822
# Test 99: p-value = 0.3896
# Test 100: p-value = 0.3559
# Test 101: p-value = 0.6333
# Test 102: p-value = 0.6151
# Test 103: p-value = 0.6935
# Test 104: p-value = 0.2802
# Test 105: p-value = 0.4262
# Test 106: p-value = 0.2913
# Test 107: p-value = 0.5779
# Test 108: p-value = 0.8483
# Test 109: p-value = 0.7918
# Test 110: p-value = 0.5935
# Test 111: p-value = 0.8632
# Test 112: p-value = 0.8014
# Test 113: p-value = 0.1639
# Test 114: p-value = 0.1268
# Test 115: p-value = 0.8624
# Test 116: p-value = 0.5963
# Test 117: p-value = 0.8427
# Test 118: p-value = 0.1129
# Test 119: p-value = 0.4841
# Test 120: p-value = 0.6450
# Test 121: p-value = 0.1936
# Test 122: p-value = 0.9957
# Test 123: p-value = 0.3271
# Test 124: p-value = 0.2743
# Test 125: p-value = 0.7239
# Test 126: p-value = 0.6164
# Test 127: p-value = 0.4684
# Test 128: p-value = 0.5952
# Test 129: p-value = 0.5311
# Test 130: p-value = 0.6677
# Test 131: p-value = 0.1093
# Test 132: p-value = 0.9010
# Test 133: p-value = 0.5344
# Test 134: p-value = 0.3200
# Test 135: p-value = 0.1085
# Test 136: p-value = 0.0424
# Test 137: p-value = 0.4604
# Test 138: p-value = 0.1902
# Test 139: p-value = 0.6085
# Test 140: p-value = 0.3367
# Test 141: p-value = 0.6159
# Test 142: p-value = 0.3777
# Test 143: p-value = 0.4878
# Test 144: p-value = 0.7110
# Test 145: p-value = 0.5227
# Test 146: p-value = 0.9965
# Test 147: p-value = 0.4184
# Test 148: p-value = 0.5337
# Test 149: p-value = 0.3308
# Test 150: p-value = 0.0271
# Test 151: p-value = 0.4474
# Test 152: p-value = 0.1602
# Test 153: p-value = 0.4340
# Test 154: p-value = 0.1685
# Test 155: p-value = 0.4094
# Test 156: p-value = 0.9622
# Test 157: p-value = 0.5253
# Test 158: p-value = 0.7809
# Test 159: p-value = 0.1883
# Test 160: p-value = 0.6383
# Test 161: p-value = 0.5213
# Test 162: p-value = 0.7548
# Test 163: p-value = 0.0705
# Test 164: p-value = 0.7216
# Test 165: p-value = 0.0838
# Test 166: p-value = 0.3560
# Test 167: p-value = 0.5891
# Test 168: p-value = 0.8428
# Test 169: p-value = 0.4109
# Test 170: p-value = 0.2801
# Test 171: p-value = 0.2098
# Test 172: p-value = 0.8645
# Test 173: p-value = 0.4443
# Test 174: p-value = 0.7792
# Test 175: p-value = 0.4782
# Test 176: p-value = 0.9761
# Test 177: p-value = 0.5729
# Test 178: p-value = 0.3875
# Test 179: p-value = 0.2227
# Test 180: p-value = 0.6058
# Test 181: p-value = 0.5104
# Test 182: p-value = 0.5110
# Test 183: p-value = 0.2000
# Test 184: p-value = 0.9697
# Test 185: p-value = 0.6444
# Test 186: p-value = 0.8863
# Test 187: p-value = 0.7508
# Test 188: p-value = 0.1483
# Test 189: p-value = 0.2437
# Test 190: p-value = 0.0317
# Test 191: p-value = 0.4736
# Test 192: p-value = 0.2197
# Test 193: p-value = 0.1493
# Test 194: p-value = 0.0495
# Test 195: p-value = 0.6534
# Test 196: p-value = 0.9587
# Test 197: p-value = 0.2405
# Test 198: p-value = 0.8654
# Test 199: p-value = 0.1819
# Test 200: p-value = 0.7958
# Test 201: p-value = 0.2659
# Test 202: p-value = 0.4734
# Test 203: p-value = 0.9145
# Test 204: p-value = 0.7237
# Test 205: p-value = 0.8026
# Test 206: p-value = 0.5490
# Test 207: p-value = 0.6181
# Test 208: p-value = 0.3860
# Test 209: p-value = 0.2080
# Test 210: p-value = 0.9448
# Test 211: p-value = 0.9628
# Test 212: p-value = 0.6608
# Test 213: p-value = 0.7808
# Test 214: p-value = 0.0153
# Test 215: p-value = 0.6861
# Test 216: p-value = 0.9513
# Test 217: p-value = 0.5635
# Test 218: p-value = 0.7523
# Test 219: p-value = 0.1680
# Test 220: p-value = 0.6973
# Test 221: p-value = 0.9960
# Test 222: p-value = 0.3950
# Test 223: p-value = 0.4253
# Test 224: p-value = 0.9231
# Test 225: p-value = 0.3235
# Test 226: p-value = 0.6659
# Test 227: p-value = 0.4936
# Test 228: p-value = 0.8492
# Test 229: p-value = 0.1448
# Test 230: p-value = 0.8999
# Test 231: p-value = 0.1076
# Test 232: p-value = 0.3417
# Test 233: p-value = 0.6279
# Test 234: p-value = 0.8602
# Test 235: p-value = 0.0468
# Test 236: p-value = 0.6141
# Test 237: p-value = 0.8879
# Test 238: p-value = 0.7764
# Test 239: p-value = 0.6034
# Test 240: p-value = 0.4376
# Test 241: p-value = 0.3742
# Test 242: p-value = 0.5524
# Test 243: p-value = 0.2497
# Test 244: p-value = 0.5670
# Test 245: p-value = 0.2232
# Test 246: p-value = 0.6518
# Test 247: p-value = 0.3354
# Test 248: p-value = 0.9557
# Test 249: p-value = 0.7225
# Test 250: p-value = 0.7250
# Test 251: p-value = 0.1727
# Test 252: p-value = 0.7661
# Test 253: p-value = 0.3447
# Test 254: p-value = 0.3132
# Test 255: p-value = 0.2546
# Test 256: p-value = 0.5197
# Test 257: p-value = 0.8250
# Test 258: p-value = 0.1685
# Test 259: p-value = 0.7565
# Test 260: p-value = 0.5217
# Test 261: p-value = 0.0236
# Test 262: p-value = 0.5851
# Test 263: p-value = 0.1283
# Test 264: p-value = 0.8171
# Test 265: p-value = 0.0024
# Test 266: p-value = 0.9747
# Test 267: p-value = 0.5134
# Test 268: p-value = 0.4280
# Test 269: p-value = 0.1063
# Test 270: p-value = 0.1934
# Test 271: p-value = 0.7551
# Test 272: p-value = 0.4707
# Test 273: p-value = 0.3849
# Test 274: p-value = 0.7852
# Test 275: p-value = 0.0880
# Test 276: p-value = 0.8464
# Test 277: p-value = 0.3284
# Test 278: p-value = 0.8307
# Test 279: p-value = 0.2644
# Test 280: p-value = 0.7283
# Test 281: p-value = 0.6941
# Test 282: p-value = 0.3239
# Test 283: p-value = 0.2329
# Test 284: p-value = 0.4720
# Test 285: p-value = 0.5544
# Test 286: p-value = 0.5026
# Test 287: p-value = 0.4114
# Test 288: p-value = 0.3910
# Test 289: p-value = 0.7204
# Test 290: p-value = 0.8276
# Test 291: p-value = 0.2803
# Test 292: p-value = 0.5937
# Test 293: p-value = 0.1204
# Test 294: p-value = 0.1339
# Test 295: p-value = 0.5389
# Test 296: p-value = 0.7006
# Test 297: p-value = 0.2755
# Test 298: p-value = 0.0473
# Test 299: p-value = 0.9026
# Test 300: p-value = 0.9814
# Test 301: p-value = 0.7486
# Test 302: p-value = 0.5509
# Test 303: p-value = 0.6268
# Test 304: p-value = 0.9615
# Test 305: p-value = 0.5570
# Test 306: p-value = 0.0792
# Test 307: p-value = 0.5419
# Test 308: p-value = 0.7591
# Test 309: p-value = 0.1971
# Test 310: p-value = 0.6223
# Test 311: p-value = 0.2897
# Test 312: p-value = 0.2004
# Test 313: p-value = 0.8225
# Test 314: p-value = 0.2202
# Test 315: p-value = 0.4084
# Test 316: p-value = 0.6796
# Test 317: p-value = 0.9398
# Test 318: p-value = 0.8563
# Test 319: p-value = 0.3863
# Test 320: p-value = 0.0411
# Test 321: p-value = 0.2865
# Test 322: p-value = 0.5580
# Test 323: p-value = 0.2593
# Test 324: p-value = 0.7759
# Test 325: p-value = 0.2978
# Test 326: p-value = 0.9739
# Test 327: p-value = 0.9604
# Test 328: p-value = 0.9820
# Test 329: p-value = 0.1734
# Test 330: p-value = 0.0249
# Test 331: p-value = 0.7136
# Test 332: p-value = 0.3710
# Test 333: p-value = 0.1996
# Test 334: p-value = 0.3924
# Test 335: p-value = 0.6123
# Test 336: p-value = 0.1852
# Test 337: p-value = 0.0278
# Test 338: p-value = 0.2549
# Test 339: p-value = 0.0878
# Test 340: p-value = 0.5386
# Test 341: p-value = 0.8600
# Test 342: p-value = 0.7903
# Test 343: p-value = 0.5585
# Test 344: p-value = 0.0349
# Test 345: p-value = 0.0745
# Test 346: p-value = 0.2812
# Test 347: p-value = 0.3047
# Test 348: p-value = 0.0872
# Test 349: p-value = 0.7852
# Test 350: p-value = 0.2402
# Test 351: p-value = 0.3770
# Test 352: p-value = 0.8723
# Test 353: p-value = 0.9366
# Test 354: p-value = 0.6251
# Test 355: p-value = 0.9105
# Test 356: p-value = 0.4231
# Test 357: p-value = 0.2869
# Test 358: p-value = 0.4494
# Test 359: p-value = 0.4065
# Test 360: p-value = 0.4081
# Test 361: p-value = 0.8114
# Test 362: p-value = 0.6653
# Test 363: p-value = 0.4753
# Test 364: p-value = 0.5951
# Test 365: p-value = 0.1478
# Test 366: p-value = 0.9372
# Test 367: p-value = 0.0223
# Test 368: p-value = 0.1354
# Test 369: p-value = 0.6832
# Test 370: p-value = 0.7005
# Test 371: p-value = 0.3562
# Test 372: p-value = 0.1498
# Test 373: p-value = 0.9070
# Test 374: p-value = 0.3636
# Test 375: p-value = 0.3253
# Test 376: p-value = 0.4590
# Test 377: p-value = 0.2911
# Test 378: p-value = 0.1281
# Test 379: p-value = 0.5485
# Test 380: p-value = 0.7606
# Test 381: p-value = 0.7682
# Test 382: p-value = 0.9983
# Test 383: p-value = 0.8147
# Test 384: p-value = 0.7062
# Test 385: p-value = 0.5797
# Test 386: p-value = 0.6630
# Test 387: p-value = 0.2102
# Test 388: p-value = 0.2638
# Test 389: p-value = 0.3401
# Test 390: p-value = 0.8696
# Test 391: p-value = 0.8666
# Test 392: p-value = 0.0636
# Test 393: p-value = 0.4743
# Test 394: p-value = 0.8533
# Test 395: p-value = 0.0356
# Test 396: p-value = 0.3082
# Test 397: p-value = 0.3422
# Test 398: p-value = 0.1676
# Test 399: p-value = 0.1261
# Test 400: p-value = 0.9150
# Test 401: p-value = 0.5097
# Test 402: p-value = 0.2947
# Test 403: p-value = 0.9378
# Test 404: p-value = 0.6211
# Test 405: p-value = 0.8392
# Test 406: p-value = 0.4948
# Test 407: p-value = 0.6605
# Test 408: p-value = 0.3089
# Test 409: p-value = 0.7131
# Test 410: p-value = 0.8112
# Test 411: p-value = 0.4291
# Test 412: p-value = 0.3054
# Test 413: p-value = 0.7884
# Test 414: p-value = 0.3695
# Test 415: p-value = 0.0498
# Test 416: p-value = 0.4883
# Test 417: p-value = 0.0439
# Test 418: p-value = 0.7933
# Test 419: p-value = 0.4568
# Test 420: p-value = 0.9914
# Test 421: p-value = 0.1030
# Test 422: p-value = 0.4334
# Test 423: p-value = 0.0475
# Test 424: p-value = 0.4741
# Test 425: p-value = 0.0184
# Test 426: p-value = 0.0098
# Test 427: p-value = 0.1818
# Test 428: p-value = 0.1828
# Test 429: p-value = 0.9077
# Test 430: p-value = 0.4922
# Test 431: p-value = 0.2392
# Test 432: p-value = 0.7884
# Test 433: p-value = 0.1977
# Test 434: p-value = 0.0502
# Test 435: p-value = 0.4953
# Test 436: p-value = 0.9603
# Test 437: p-value = 0.0101
# Test 438: p-value = 0.7297
# Test 439: p-value = 0.9881
# Test 440: p-value = 0.2934
# Test 441: p-value = 0.5665
# Test 442: p-value = 0.2784
# Test 443: p-value = 0.1959
# Test 444: p-value = 0.2197
# Test 445: p-value = 0.2123
# Test 446: p-value = 0.1158
# Test 447: p-value = 0.5146
# Test 448: p-value = 0.3505
# Test 449: p-value = 0.9427
# Test 450: p-value = 0.6608
# Test 451: p-value = 0.0208
# Test 452: p-value = 0.7307
# Test 453: p-value = 0.7174
# Test 454: p-value = 0.8499
# Test 455: p-value = 0.6751
# Test 456: p-value = 0.8305
# Test 457: p-value = 0.9662
# Test 458: p-value = 0.5869
# Test 459: p-value = 0.3226
# Test 460: p-value = 0.9589
# Test 461: p-value = 0.8899
# Test 462: p-value = 0.2659
# Test 463: p-value = 0.7708
# Test 464: p-value = 0.5732
# Test 465: p-value = 0.2756
# Test 466: p-value = 0.6463
# Test 467: p-value = 0.8102
# Test 468: p-value = 0.6844
# Test 469: p-value = 0.8263
# Test 470: p-value = 0.5968
# Test 471: p-value = 0.5705
# Test 472: p-value = 0.8614
# Test 473: p-value = 0.1399
# Test 474: p-value = 0.5471
# Test 475: p-value = 0.6356
# Test 476: p-value = 0.7670
# Test 477: p-value = 0.3795
# Test 478: p-value = 0.3689
# Test 479: p-value = 0.2697
# Test 480: p-value = 0.0620
# Test 481: p-value = 0.9284
# Test 482: p-value = 0.3773
# Test 483: p-value = 0.1656
# Test 484: p-value = 0.0460
# Test 485: p-value = 0.0933
# Test 486: p-value = 0.6530
# Test 487: p-value = 0.7151
# Test 488: p-value = 0.1235
# Test 489: p-value = 0.9100
# Test 490: p-value = 0.2830
# Test 491: p-value = 0.3487
# Test 492: p-value = 0.1319
# Test 493: p-value = 0.6187
# Test 494: p-value = 0.7946
# Test 495: p-value = 0.6083
# Test 496: p-value = 0.5531
# Test 497: p-value = 0.9841
# Test 498: p-value = 0.0544
# Test 499: p-value = 0.0917
# Test 500: p-value = 0.9002
# Test 501: p-value = 0.3771
# Test 502: p-value = 0.1630
# Test 503: p-value = 0.6319
# Test 504: p-value = 0.3727
# Test 505: p-value = 0.7439
# Test 506: p-value = 0.6056
# Test 507: p-value = 0.7038
# Test 508: p-value = 0.1094
# Test 509: p-value = 0.5001
# Test 510: p-value = 0.3846
# Test 511: p-value = 0.2652
# Test 512: p-value = 0.2486
# Test 513: p-value = 0.0335
# Test 514: p-value = 0.7753
# Test 515: p-value = 0.0585
# Test 516: p-value = 0.1697
# Test 517: p-value = 0.2984
# Test 518: p-value = 0.8889
# Test 519: p-value = 0.5205
# Test 520: p-value = 0.5399
# Test 521: p-value = 0.2441
# Test 522: p-value = 0.8179
# Test 523: p-value = 0.0030
# Test 524: p-value = 0.1024
# Test 525: p-value = 0.2224
# Test 526: p-value = 0.8600
# Test 527: p-value = 0.3715
# Test 528: p-value = 0.8831
# Test 529: p-value = 0.2531
# Test 530: p-value = 0.9935
# Test 531: p-value = 0.5134
# Test 532: p-value = 0.1437
# Test 533: p-value = 0.6341
# Test 534: p-value = 0.2602
# Test 535: p-value = 0.6628
# Test 536: p-value = 0.1584
# Test 537: p-value = 0.9999
# Test 538: p-value = 0.1478
# Test 539: p-value = 0.8414
# Test 540: p-value = 0.3627
# Test 541: p-value = 0.8283
# Test 542: p-value = 0.4281
# Test 543: p-value = 0.1143
# Test 544: p-value = 0.0991
# Test 545: p-value = 0.1024
# Test 546: p-value = 0.7387
# Test 547: p-value = 0.7819
# Test 548: p-value = 0.0303
# Test 549: p-value = 0.6837
# Test 550: p-value = 0.7651
# Test 551: p-value = 0.1770
# Test 552: p-value = 0.3166
# Test 553: p-value = 0.6927
# Test 554: p-value = 0.0606
# Test 555: p-value = 0.7534
# Test 556: p-value = 0.7705
# Test 557: p-value = 0.3405
# Test 558: p-value = 0.2952
# Test 559: p-value = 0.1153
# Test 560: p-value = 0.8902
# Test 561: p-value = 0.6432
# Test 562: p-value = 0.9311
# Test 563: p-value = 0.6049
# Test 564: p-value = 0.0229
# Test 565: p-value = 0.8933
# Test 566: p-value = 0.9244
# Test 567: p-value = 0.8524
# Test 568: p-value = 0.2350
# Test 569: p-value = 0.4306
# Test 570: p-value = 0.1671
# Test 571: p-value = 0.7270
# Test 572: p-value = 0.6245
# Test 573: p-value = 0.8007
# Test 574: p-value = 0.1987
# Test 575: p-value = 0.3503
# Test 576: p-value = 0.2006
# Test 577: p-value = 0.4159
# Test 578: p-value = 0.6148
# Test 579: p-value = 0.7855
# Test 580: p-value = 0.5650
# Test 581: p-value = 0.4208
# Test 582: p-value = 0.4356
# Test 583: p-value = 0.6386
# Test 584: p-value = 0.1619
# Test 585: p-value = 0.1969
# Test 586: p-value = 0.8668
# Test 587: p-value = 0.7829
# Test 588: p-value = 0.8252
# Test 589: p-value = 0.8182
# Test 590: p-value = 0.5905
# Test 591: p-value = 0.7617
# Test 592: p-value = 0.8712
# Test 593: p-value = 0.0273
# Test 594: p-value = 0.1408
# Test 595: p-value = 0.9863
# Test 596: p-value = 0.4388
# Test 597: p-value = 0.1290
# Test 598: p-value = 0.4601
# Test 599: p-value = 0.2261
# Test 600: p-value = 0.1520
# Test 601: p-value = 0.0623
# Test 602: p-value = 0.0068
# Test 603: p-value = 0.6098
# Test 604: p-value = 0.3476
# Test 605: p-value = 0.6774
# Test 606: p-value = 0.5773
# Test 607: p-value = 0.3751
# Test 608: p-value = 0.0970
# Test 609: p-value = 0.2091
# Test 610: p-value = 0.6089
# Test 611: p-value = 0.4972
# Test 612: p-value = 0.2922
# Test 613: p-value = 0.1247
# Test 614: p-value = 0.8023
# Test 615: p-value = 0.7215
# Test 616: p-value = 0.9596
# Test 617: p-value = 0.4014
# Test 618: p-value = 0.6339
# Test 619: p-value = 0.5793
# Test 620: p-value = 0.9248
# Test 621: p-value = 0.5352
# Test 622: p-value = 0.9003
# Test 623: p-value = 0.2156
# Test 624: p-value = 0.6596
# Test 625: p-value = 0.4482
# Test 626: p-value = 0.7557
# Test 627: p-value = 0.0399
# Test 628: p-value = 0.0912
# Test 629: p-value = 0.5967
# Test 630: p-value = 0.7110
# Test 631: p-value = 0.9784
# Test 632: p-value = 0.6035
# Test 633: p-value = 0.0520
# Test 634: p-value = 0.5753
# Test 635: p-value = 0.3274
# Test 636: p-value = 0.1610
# Test 637: p-value = 0.8377
# Test 638: p-value = 0.0028
# Test 639: p-value = 0.3670
# Test 640: p-value = 0.8806
# Test 641: p-value = 0.6419
# Test 642: p-value = 0.2623
# Test 643: p-value = 0.8508
# Test 644: p-value = 0.4681
# Test 645: p-value = 0.6031
# Test 646: p-value = 0.0415
# Test 647: p-value = 0.1879
# Test 648: p-value = 0.2689
# Test 649: p-value = 0.7926
# Test 650: p-value = 0.2703
# Test 651: p-value = 0.7810
# Test 652: p-value = 0.2463
# Test 653: p-value = 0.9594
# Test 654: p-value = 0.8596
# Test 655: p-value = 0.3929
# Test 656: p-value = 0.5689
# Test 657: p-value = 0.5555
# Test 658: p-value = 0.9157
# Test 659: p-value = 0.2748
# Test 660: p-value = 0.2041
# Test 661: p-value = 0.3995
# Test 662: p-value = 0.7331
# Test 663: p-value = 0.0477
# Test 664: p-value = 0.4974
# Test 665: p-value = 0.6161
# Test 666: p-value = 0.6739
# Test 667: p-value = 0.1878
# Test 668: p-value = 0.3617
# Test 669: p-value = 0.8507
# Test 670: p-value = 0.4352
# Test 671: p-value = 0.3720
# Test 672: p-value = 0.0050
# Test 673: p-value = 0.2398
# Test 674: p-value = 0.5819
# Test 675: p-value = 0.5487
# Test 676: p-value = 0.7921
# Test 677: p-value = 0.4793
# Test 678: p-value = 0.7725
# Test 679: p-value = 0.8367
# Test 680: p-value = 0.4472
# Test 681: p-value = 0.2334
# Test 682: p-value = 0.3465
# Test 683: p-value = 0.4998
# Test 684: p-value = 0.7362
# Test 685: p-value = 0.5138
# Test 686: p-value = 0.1082
# Test 687: p-value = 0.0869
# Test 688: p-value = 0.6769
# Test 689: p-value = 0.6563
# Test 690: p-value = 0.8957
# Test 691: p-value = 0.1869
# Test 692: p-value = 0.9779
# Test 693: p-value = 0.7143
# Test 694: p-value = 0.3286
# Test 695: p-value = 0.4716
# Test 696: p-value = 0.1237
# Test 697: p-value = 0.7607
# Test 698: p-value = 0.6567
# Test 699: p-value = 0.9005
# Test 700: p-value = 0.3996
# Test 701: p-value = 0.5729
# Test 702: p-value = 0.9749
# Test 703: p-value = 0.2779
# Test 704: p-value = 0.4935
# Test 705: p-value = 0.1797
# Test 706: p-value = 0.6610
# Test 707: p-value = 0.7617
# Test 708: p-value = 0.5024
# Test 709: p-value = 0.5913
# Test 710: p-value = 0.1905
# Test 711: p-value = 0.9429
# Test 712: p-value = 0.2580
# Test 713: p-value = 0.5070
# Test 714: p-value = 0.8087
# Test 715: p-value = 0.1588
# Test 716: p-value = 0.2169
# Test 717: p-value = 0.9372
# Test 718: p-value = 0.4605
# Test 719: p-value = 0.4367
# Test 720: p-value = 0.5370
# Test 721: p-value = 0.0269
# Test 722: p-value = 0.2758
# Test 723: p-value = 0.4765
# Test 724: p-value = 0.6591
# Test 725: p-value = 0.8974
# Test 726: p-value = 0.2809
# Test 727: p-value = 0.8984
# Test 728: p-value = 0.9234
# Test 729: p-value = 0.2310
# Test 730: p-value = 0.2460
# Test 731: p-value = 0.9155
# Test 732: p-value = 0.1322
# Test 733: p-value = 0.9711
# Test 734: p-value = 0.6743
# Test 735: p-value = 0.7756
# Test 736: p-value = 0.1038
# Test 737: p-value = 0.0886
# Test 738: p-value = 0.7257
# Test 739: p-value = 0.0647
# Test 740: p-value = 0.7777
# Test 741: p-value = 0.2354
# Test 742: p-value = 0.6677
# Test 743: p-value = 0.3952
# Test 744: p-value = 0.6447
# Test 745: p-value = 0.0913
# Test 746: p-value = 0.4890
# Test 747: p-value = 0.5722
# Test 748: p-value = 0.3545
# Test 749: p-value = 0.5195
# Test 750: p-value = 0.1714
# Test 751: p-value = 0.0609
# Test 752: p-value = 0.4225
# Test 753: p-value = 0.6038
# Test 754: p-value = 0.5814
# Test 755: p-value = 0.8285
# Test 756: p-value = 0.2066
# Test 757: p-value = 0.5180
# Test 758: p-value = 0.8134
# Test 759: p-value = 0.5176
# Test 760: p-value = 0.9553
# Test 761: p-value = 0.6943
# Test 762: p-value = 0.2875
# Test 763: p-value = 0.9343
# Test 764: p-value = 0.5677
# Test 765: p-value = 0.3055
# Test 766: p-value = 0.9506
# Test 767: p-value = 0.5239
# Test 768: p-value = 0.4864
# Test 769: p-value = 0.7172
# Test 770: p-value = 0.0745
# Test 771: p-value = 0.6414
# Test 772: p-value = 0.6089
# Test 773: p-value = 0.3461
# Test 774: p-value = 0.5657
# Test 775: p-value = 0.9488
# Test 776: p-value = 0.2873
# Test 777: p-value = 0.0181
# Test 778: p-value = 0.6286
# Test 779: p-value = 0.4938
# Test 780: p-value = 0.7595
# Test 781: p-value = 0.6261
# Test 782: p-value = 0.3341
# Test 783: p-value = 0.7243
# Test 784: p-value = 0.1573
# Test 785: p-value = 0.7964
# Test 786: p-value = 0.5681
# Test 787: p-value = 0.5026
# Test 788: p-value = 0.4002
# Test 789: p-value = 0.0255
# Test 790: p-value = 0.0610
# Test 791: p-value = 0.8442
# Test 792: p-value = 0.6978
# Test 793: p-value = 0.5955
# Test 794: p-value = 0.1596
# Test 795: p-value = 0.3918
# Test 796: p-value = 0.2800
# Test 797: p-value = 0.5954
# Test 798: p-value = 0.7951
# Test 799: p-value = 0.2723
# Test 800: p-value = 0.7652
# Test 801: p-value = 0.7649
# Test 802: p-value = 0.3555
# Test 803: p-value = 0.8532
# Test 804: p-value = 0.0342
# Test 805: p-value = 0.8780
# Test 806: p-value = 0.6056
# Test 807: p-value = 0.5884
# Test 808: p-value = 0.7126
# Test 809: p-value = 0.3196
# Test 810: p-value = 0.8974
# Test 811: p-value = 0.9981
# Test 812: p-value = 0.1694
# Test 813: p-value = 0.4637
# Test 814: p-value = 0.4767
# Test 815: p-value = 0.4716
# Test 816: p-value = 0.4677
# Test 817: p-value = 0.0905
# Test 818: p-value = 0.1993
# Test 819: p-value = 0.7611
# Test 820: p-value = 0.2209
# Test 821: p-value = 0.4809
# Test 822: p-value = 0.3323
# Test 823: p-value = 0.9966
# Test 824: p-value = 0.3004
# Test 825: p-value = 0.3794
# Test 826: p-value = 0.6952
# Test 827: p-value = 0.2533
# Test 828: p-value = 0.0261
# Test 829: p-value = 0.6786
# Test 830: p-value = 0.4657
# Test 831: p-value = 0.5163
# Test 832: p-value = 0.4036
# Test 833: p-value = 0.1049
# Test 834: p-value = 0.4753
# Test 835: p-value = 0.2798
# Test 836: p-value = 0.8185
# Test 837: p-value = 0.6599
# Test 838: p-value = 0.7573
# Test 839: p-value = 0.5434
# Test 840: p-value = 0.4595
# Test 841: p-value = 0.9115
# Test 842: p-value = 0.6779
# Test 843: p-value = 0.9237
# Test 844: p-value = 0.1284
# Test 845: p-value = 0.5255
# Test 846: p-value = 0.3176
# Test 847: p-value = 0.4696
# Test 848: p-value = 0.3698
# Test 849: p-value = 0.6149
# Test 850: p-value = 0.3806
# Test 851: p-value = 0.8775
# Test 852: p-value = 0.1426
# Test 853: p-value = 0.3014
# Test 854: p-value = 0.8832
# Test 855: p-value = 0.3145
# Test 856: p-value = 0.4131
# Test 857: p-value = 0.2406
# Test 858: p-value = 0.6525
# Test 859: p-value = 0.6954
# Test 860: p-value = 0.1817
# Test 861: p-value = 0.3275
# Test 862: p-value = 0.5244
# Test 863: p-value = 0.3304
# Test 864: p-value = 0.7752
# Test 865: p-value = 0.9603
# Test 866: p-value = 0.9456
# Test 867: p-value = 0.7334
# Test 868: p-value = 0.8720
# Test 869: p-value = 0.7310
# Test 870: p-value = 0.6273
# Test 871: p-value = 0.1430
# Test 872: p-value = 0.4108
# Test 873: p-value = 0.5135
# Test 874: p-value = 0.5287
# Test 875: p-value = 0.1716
# Test 876: p-value = 0.4051
# Test 877: p-value = 0.2086
# Test 878: p-value = 0.8679
# Test 879: p-value = 0.2929
# Test 880: p-value = 0.6383
# Test 881: p-value = 0.3762
# Test 882: p-value = 0.2978
# Test 883: p-value = 0.0290
# Test 884: p-value = 0.5130
# Test 885: p-value = 0.6140
# Test 886: p-value = 0.6494
# Test 887: p-value = 0.6530
# Test 888: p-value = 0.6607
# Test 889: p-value = 0.1704
# Test 890: p-value = 0.5947
# Test 891: p-value = 0.3259
# Test 892: p-value = 0.4539
# Test 893: p-value = 0.0279
# Test 894: p-value = 0.6005
# Test 895: p-value = 0.6639
# Test 896: p-value = 0.8645
# Test 897: p-value = 0.4000
# Test 898: p-value = 0.6744
# Test 899: p-value = 0.8349
# Test 900: p-value = 0.6307
# Test 901: p-value = 0.8234
# Test 902: p-value = 0.0394
# Test 903: p-value = 0.3208
# Test 904: p-value = 0.2817
# Test 905: p-value = 0.8379
# Test 906: p-value = 0.0221
# Test 907: p-value = 0.3444
# Test 908: p-value = 0.7912
# Test 909: p-value = 0.8018
# Test 910: p-value = 0.3598
# Test 911: p-value = 0.5664
# Test 912: p-value = 0.3754
# Test 913: p-value = 0.6614
# Test 914: p-value = 0.6532
# Test 915: p-value = 0.8349
# Test 916: p-value = 0.6032
# Test 917: p-value = 0.0987
# Test 918: p-value = 0.8257
# Test 919: p-value = 0.9438
# Test 920: p-value = 0.0612
# Test 921: p-value = 0.5660
# Test 922: p-value = 0.3287
# Test 923: p-value = 0.6906
# Test 924: p-value = 0.4648
# Test 925: p-value = 0.3191
# Test 926: p-value = 0.3438
# Test 927: p-value = 0.1565
# Test 928: p-value = 0.4704
# Test 929: p-value = 0.0485
# Test 930: p-value = 0.8555
# Test 931: p-value = 0.1728
# Test 932: p-value = 0.7909
# Test 933: p-value = 0.0831
# Test 934: p-value = 0.7212
# Test 935: p-value = 0.9709
# Test 936: p-value = 0.3365
# Test 937: p-value = 0.8897
# Test 938: p-value = 0.6805
# Test 939: p-value = 0.2696
# Test 940: p-value = 0.3499
# Test 941: p-value = 0.1675
# Test 942: p-value = 0.2466
# Test 943: p-value = 0.8070
# Test 944: p-value = 0.2604
# Test 945: p-value = 0.7445
# Test 946: p-value = 0.4043
# Test 947: p-value = 0.4718
# Test 948: p-value = 0.3185
# Test 949: p-value = 0.1889
# Test 950: p-value = 0.5727
# Test 951: p-value = 0.6657
# Test 952: p-value = 0.0628
# Test 953: p-value = 0.6094
# Test 954: p-value = 0.2844
# Test 955: p-value = 0.2363
# Test 956: p-value = 0.1868
# Test 957: p-value = 0.8654
# Test 958: p-value = 0.9311
# Test 959: p-value = 0.4751
# Test 960: p-value = 0.2910
# Test 961: p-value = 0.2903
# Test 962: p-value = 0.3689
# Test 963: p-value = 0.1728
# Test 964: p-value = 0.8891
# Test 965: p-value = 0.3310
# Test 966: p-value = 0.4592
# Test 967: p-value = 0.5173
# Test 968: p-value = 0.7181
# Test 969: p-value = 0.5649
# Test 970: p-value = 0.0944
# Test 971: p-value = 0.3086
# Test 972: p-value = 0.2187
# Test 973: p-value = 0.8671
# Test 974: p-value = 0.9810
# Test 975: p-value = 0.9573
# Test 976: p-value = 0.3848
# Test 977: p-value = 0.1875
# Test 978: p-value = 0.3569
# Test 979: p-value = 0.6489
# Test 980: p-value = 0.4302
# Test 981: p-value = 0.7901
# Test 982: p-value = 0.3617
# Test 983: p-value = 0.4543
# Test 984: p-value = 0.9620
# Test 985: p-value = 0.0933
# Test 986: p-value = 0.0338
# Test 987: p-value = 0.9798
# Test 988: p-value = 0.4702
# Test 989: p-value = 0.9108
# Test 990: p-value = 0.2838
# Test 991: p-value = 0.6851
# Test 992: p-value = 0.4912
# Test 993: p-value = 0.0245
# Test 994: p-value = 0.4805
# Test 995: p-value = 0.9809
# Test 996: p-value = 0.1061
# Test 997: p-value = 0.8275
# Test 998: p-value = 0.0615
# Test 999: p-value = 0.4552
# Test 1000: p-value = 0.3310
# Percentage of significant p-values (p < 0.05): 5.00%

# %% [markdown]
# Second, once you have the simulated p-values, apply both methods to address the multiple comparisons problem.

# %%
import numpy as np
from scipy import stats

# Set random seed for reproducibility
np.random.seed(42)

# Number of simulations and sample size
num_tests = 1000
sample_size = 30

# Generate p-values from t-tests
p_values = []
for _ in range(num_tests):
    # Generate two samples from the same normal distribution (equal means and std)
    sample1 = np.random.normal(loc=0, scale=1, size=sample_size)
    sample2 = np.random.normal(loc=0, scale=1, size=sample_size)

    # Perform two-sample t-test
    t_stat, p_val = stats.ttest_ind(sample1, sample2)
    p_values.append(p_val)

p_values = np.array(p_values)

# Bonferroni correction
alpha = 0.05
bonferroni_threshold = alpha / num_tests
bonferroni_significant = np.sum(p_values < bonferroni_threshold)

# Benjamini-Hochberg correction
sorted_p_values = np.sort(p_values)
bh_thresholds = (np.arange(1, num_tests+1) / num_tests) * alpha
bh_significant = np.sum(sorted_p_values < bh_thresholds)

# Print results
print(f"Number of significant results before correction (p < 0.05): {np.sum(p_values < 0.05)}")
print(f"Number of significant results after Bonferroni correction: {bonferroni_significant}")
print(f"Number of significant results after Benjamini-Hochberg correction: {bh_significant}")
# Out:
# Number of significant results before correction (p < 0.05): 41
# Number of significant results after Bonferroni correction: 0
# Number of significant results after Benjamini-Hochberg correction: 0

# %% [markdown]
# Third, set the sample 1 and sample 2 means to be 1 and 2 respectively, and re-run the exercise. What do you notice? What if you make the difference between means even greater?
#
# * As the difference between the means increases (from 1 vs. 2 to 1 vs. 3), you should see even more tests being classified as significant both before and after correction.

# %%
import numpy as np
from scipy import stats

# Set random seed for reproducibility
np.random.seed(42)

# Number of simulations and sample size
num_tests = 1000
sample_size = 30

# Means for the two samples
mean1 = 1  # Mean of sample 1
mean2 = 2  # Mean of sample 2

# Generate p-values from t-tests with difference in means (mean1=1, mean2=2)
p_values_diff_means = []
for _ in range(num_tests):
    # Generate two samples from normal distributions (mean1 = 1, mean2 = 2)
    sample1 = np.random.normal(loc=mean1, scale=1, size=sample_size)
    sample2 = np.random.normal(loc=mean2, scale=1, size=sample_size)

    # Perform two-sample t-test
    t_stat, p_val = stats.ttest_ind(sample1, sample2)
    p_values_diff_means.append(p_val)

p_values_diff_means = np.array(p_values_diff_means)

# Bonferroni correction
alpha = 0.05
bonferroni_threshold = alpha / num_tests
bonferroni_significant_diff_means = np.sum(p_values_diff_means < bonferroni_threshold)

# Benjamini-Hochberg correction
sorted_p_values_diff_means = np.sort(p_values_diff_means)
bh_thresholds = (np.arange(1, num_tests+1) / num_tests) * alpha
bh_significant_diff_means = np.sum(sorted_p_values_diff_means < bh_thresholds)

# Number of significant results before and after corrections
significant_before_correction_diff_means = np.sum(p_values_diff_means < 0.05)

# Print results
print(f"Significant before correction (p < 0.05): {significant_before_correction_diff_means}")
print(f"Significant after Bonferroni correction: {bonferroni_significant_diff_means}")
print(f"Significant after Benjamini-Hochberg correction: {bh_significant_diff_means}")
# Out:
# Significant before correction (p < 0.05): 973
# Significant after Bonferroni correction: 305
# Significant after Benjamini-Hochberg correction: 971

# %% [markdown]
# sample 1 mean = 1
# sample 2 mean = 3

# %%
import numpy as np
from scipy import stats

# Set random seed for reproducibility
np.random.seed(42)

# Number of simulations and sample size
num_tests = 1000
sample_size = 30

# Means for the two samples
mean1 = 1
mean2 = 3

# Generate p-values from t-tests with greater difference in means
p_values_greater_diff = []
for _ in range(num_tests):
    # Generate two samples from normal distributions (mean1 = 1, mean2 = 3)
    sample1 = np.random.normal(loc=mean1, scale=1, size=sample_size)
    sample2 = np.random.normal(loc=mean2, scale=1, size=sample_size)

    # Perform two-sample t-test
    t_stat, p_val = stats.ttest_ind(sample1, sample2)
    p_values_greater_diff.append(p_val)

p_values_greater_diff = np.array(p_values_greater_diff)

# Bonferroni correction
alpha = 0.05
bonferroni_threshold = alpha / num_tests
bonferroni_significant_greater_diff = np.sum(p_values_greater_diff < bonferroni_threshold)

# Benjamini-Hochberg correction
sorted_p_values_greater_diff = np.sort(p_values_greater_diff)
bh_thresholds = (np.arange(1, num_tests+1) / num_tests) * alpha
bh_significant_greater_diff = np.sum(sorted_p_values_greater_diff < bh_thresholds)

# Number of significant results before and after corrections
significant_before_correction_greater_diff = np.sum(p_values_greater_diff < 0.05)

# Print results
print(f"Significant before correction (p < 0.05): {significant_before_correction_greater_diff}")
print(f"Significant after Bonferroni correction: {bonferroni_significant_greater_diff}")
print(f"Significant after Benjamini-Hochberg correction: {bh_significant_greater_diff}")
# Out:
# Significant before correction (p < 0.05): 1000
# Significant after Bonferroni correction: 1000
# Significant after Benjamini-Hochberg correction: 1000
